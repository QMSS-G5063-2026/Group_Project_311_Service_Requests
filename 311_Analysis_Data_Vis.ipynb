# %%
import pandas as pd

# %% [markdown]
# ### Note to Team: We are using Relative Paths. Place the dataset in the same folder as this notebook. If the file is missing, the script will automatically download it from the NYC Open Data link provided by Maryla.

# %%
import pandas as pd
import requests
import os
from io import StringIO

# --- CONFIG ---
BASE_URL = "https://data.cityofnewyork.us/resource/erm2-nwe9.csv"
FILENAME = "311_Service_Requests_2024_2025.csv"

LIMIT = 50000
offset = 0
total_rows = 0
first_chunk = True

# --- CLEAN START ---
if os.path.exists(FILENAME):
    os.remove(FILENAME)
    print("Old file removed.")

print("Starting download...\n")

# --- PAGED DOWNLOAD LOOP ---
while True:
    params = {
        "$select": ",".join([
            "unique_key", "created_date", "closed_date", "agency", "agency_name",
            "complaint_type", "descriptor", "location_type", "incident_zip",
            "incident_address", "street_name", "cross_street_1", "cross_street_2",
            "intersection_street_1", "intersection_street_2", "address_type",
            "city", "landmark", "facility_type", "status", "due_date",
            "resolution_description", "resolution_action_updated_date",
            "community_board", "bbl", "borough", "x_coordinate_state_plane",
            "y_coordinate_state_plane", "open_data_channel_type", "park_borough",
            "latitude", "longitude", "location"
        ]),
        "$where": (
            "created_date between '2024-01-01T00:00:00' "
            "and '2025-12-31T23:59:59' AND agency != 'HPD'"
        ),
        "$order": "created_date DESC",
        "$limit": LIMIT,
        "$offset": offset
    }

    try:
        response = requests.get(BASE_URL, params=params, timeout=120)
        
        if response.status_code != 200:
            print(f"❌ Error at offset {offset}")
            print("Status:", response.status_code)
            print(response.text[:1000])
            break

        chunk = pd.read_csv(
            StringIO(response.text),
            low_memory=False,
            dtype={
                "facility_type": "string",
                "due_date": "string"
            }
        )

        rows = len(chunk)

        if rows == 0:
            print("\n✅ No more data. Finished.")
            break

        total_rows += rows

        print(f"Offset {offset:>8} | Rows: {rows:>6} | Total: {total_rows:>8}")

        # Write to CSV (append mode after first chunk)
        chunk.to_csv(
            FILENAME,
            mode="w" if first_chunk else "a",
            index=False,
            header=first_chunk
        )

        first_chunk = False

        if rows < LIMIT:
            print("\n✅ Last chunk received.")
            break

        offset += LIMIT

    except Exception as e:
        print(f"❌ Failed at offset {offset}: {e}")
        break

print(f"\n🏁 DONE — Total rows saved: {total_rows:,}")
print(f"📁 File saved as: {FILENAME}")
# Out:
# Starting download...
#
# Offset        0 | Rows:  50000 | Total:    50000
# Offset    50000 | Rows:  50000 | Total:   100000
# Offset   100000 | Rows:  50000 | Total:   150000
# Offset   150000 | Rows:  50000 | Total:   200000
# Offset   200000 | Rows:  50000 | Total:   250000
# Offset   250000 | Rows:  50000 | Total:   300000
# Offset   300000 | Rows:  50000 | Total:   350000
# Offset   350000 | Rows:  50000 | Total:   400000
# Offset   400000 | Rows:  50000 | Total:   450000
# Offset   450000 | Rows:  50000 | Total:   500000
# Offset   500000 | Rows:  50000 | Total:   550000
# Offset   550000 | Rows:  50000 | Total:   600000
# Offset   600000 | Rows:  50000 | Total:   650000
# Offset   650000 | Rows:  50000 | Total:   700000
# Offset   700000 | Rows:  50000 | Total:   750000
# Offset   750000 | Rows:  50000 | Total:   800000
# Offset   800000 | Rows:  50000 | Total:   850000
# Offset   850000 | Rows:  50000 | Total:   900000
# Offset   900000 | Rows:  50000 | Total:   950000
# Offset   950000 | Rows:  50000 | Total:  1000000
# Offset  1000000 | Rows:  50000 | Total:  1050000
# Offset  1050000 | Rows:  50000 | Total:  1100000
# Offset  1100000 | Rows:  50000 | Total:  1150000
# Offset  1150000 | Rows:  50000 | Total:  1200000
# Offset  1200000 | Rows:  50000 | Total:  1250000
# Offset  1250000 | Rows:  50000 | Total:  1300000
# Offset  1300000 | Rows:  50000 | Total:  1350000
# Offset  1350000 | Rows:  50000 | Total:  1400000
# Offset  1400000 | Rows:  50000 | Total:  1450000
# Offset  1450000 | Rows:  50000 | Total:  1500000
# Offset  1500000 | Rows:  50000 | Total:  1550000
# Offset  1550000 | Rows:  50000 | Total:  1600000
# Offset  1600000 | Rows:  50000 | Total:  1650000
# Offset  1650000 | Rows:  50000 | Total:  1700000
# Offset  1700000 | Rows:  50000 | Total:  1750000
# Offset  1750000 | Rows:  50000 | Total:  1800000
# Offset  1800000 | Rows:  50000 | Total:  1850000
# Offset  1850000 | Rows:  50000 | Total:  1900000
# Offset  1900000 | Rows:  50000 | Total:  1950000
# Offset  1950000 | Rows:  50000 | Total:  2000000
# Offset  2000000 | Rows:  50000 | Total:  2050000
# Offset  2050000 | Rows:  50000 | Total:  2100000
# Offset  2100000 | Rows:  50000 | Total:  2150000
# Offset  2150000 | Rows:  50000 | Total:  2200000
# Offset  2200000 | Rows:  50000 | Total:  2250000
# Offset  2250000 | Rows:  50000 | Total:  2300000
# Offset  2300000 | Rows:  50000 | Total:  2350000
# Offset  2350000 | Rows:  50000 | Total:  2400000
# Offset  2400000 | Rows:  50000 | Total:  2450000
# Offset  2450000 | Rows:  50000 | Total:  2500000
# Offset  2500000 | Rows:  50000 | Total:  2550000
# Offset  2550000 | Rows:  50000 | Total:  2600000
# Offset  2600000 | Rows:  50000 | Total:  2650000
# Offset  2650000 | Rows:  50000 | Total:  2700000
# Offset  2700000 | Rows:  50000 | Total:  2750000
# Offset  2750000 | Rows:  50000 | Total:  2800000
# Offset  2800000 | Rows:  50000 | Total:  2850000
# Offset  2850000 | Rows:  50000 | Total:  2900000
# Offset  2900000 | Rows:  50000 | Total:  2950000
# Offset  2950000 | Rows:  50000 | Total:  3000000
# Offset  3000000 | Rows:  50000 | Total:  3050000
# Offset  3050000 | Rows:  50000 | Total:  3100000
# Offset  3100000 | Rows:  50000 | Total:  3150000
# Offset  3150000 | Rows:  50000 | Total:  3200000
# Offset  3200000 | Rows:  50000 | Total:  3250000
# Offset  3250000 | Rows:  50000 | Total:  3300000
# Offset  3300000 | Rows:  50000 | Total:  3350000
# Offset  3350000 | Rows:  50000 | Total:  3400000
# Offset  3400000 | Rows:  50000 | Total:  3450000
# Offset  3450000 | Rows:  50000 | Total:  3500000
# Offset  3500000 | Rows:  50000 | Total:  3550000
# Offset  3550000 | Rows:  50000 | Total:  3600000
# Offset  3600000 | Rows:  50000 | Total:  3650000
# Offset  3650000 | Rows:  50000 | Total:  3700000
# Offset  3700000 | Rows:  50000 | Total:  3750000
# Offset  3750000 | Rows:  50000 | Total:  3800000
# Offset  3800000 | Rows:  50000 | Total:  3850000
# Offset  3850000 | Rows:  50000 | Total:  3900000
# Offset  3900000 | Rows:  50000 | Total:  3950000
# Offset  3950000 | Rows:  50000 | Total:  4000000
# Offset  4000000 | Rows:  50000 | Total:  4050000
# Offset  4050000 | Rows:  50000 | Total:  4100000
# Offset  4100000 | Rows:  50000 | Total:  4150000
# Offset  4150000 | Rows:  50000 | Total:  4200000
# Offset  4200000 | Rows:  50000 | Total:  4250000
# Offset  4250000 | Rows:  50000 | Total:  4300000
# Offset  4300000 | Rows:  50000 | Total:  4350000
# Offset  4350000 | Rows:  50000 | Total:  4400000
# Offset  4400000 | Rows:  50000 | Total:  4450000
# Offset  4450000 | Rows:  50000 | Total:  4500000
# Offset  4500000 | Rows:  50000 | Total:  4550000
# Offset  4550000 | Rows:  50000 | Total:  4600000
# Offset  4600000 | Rows:  50000 | Total:  4650000
# Offset  4650000 | Rows:  50000 | Total:  4700000
# Offset  4700000 | Rows:  50000 | Total:  4750000
# Offset  4750000 | Rows:  50000 | Total:  4800000
# Offset  4800000 | Rows:  50000 | Total:  4850000
# Offset  4850000 | Rows:  50000 | Total:  4900000
# Offset  4900000 | Rows:  50000 | Total:  4950000
# Offset  4950000 | Rows:  50000 | Total:  5000000
# Offset  5000000 | Rows:  50000 | Total:  5050000
# Offset  5050000 | Rows:  50000 | Total:  5100000
# Offset  5100000 | Rows:  50000 | Total:  5150000
# Offset  5150000 | Rows:  50000 | Total:  5200000
# Offset  5200000 | Rows:  50000 | Total:  5250000
# Offset  5250000 | Rows:  50000 | Total:  5300000
# Offset  5300000 | Rows:  50000 | Total:  5350000
# Offset  5350000 | Rows:  50000 | Total:  5400000
# Offset  5400000 | Rows:  50000 | Total:  5450000
# Offset  5450000 | Rows:  50000 | Total:  5500000
# Offset  5500000 | Rows:  50000 | Total:  5550000
# Offset  5550000 | Rows:  50000 | Total:  5600000
# Offset  5600000 | Rows:   3347 | Total:  5603347
#
# ✅ Last chunk received.
#
# 🏁 DONE — Total rows saved: 5,603,347
# 📁 File saved as: 311_Service_Requests_2024_2025_full.csv

# %% [markdown]
# https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2020-to-Present/erm2-nwe9/explore/query/SELECT%0A%20%20%60unique_key%60%2C%0A%20%20%60created_date%60%2C%0A%20%20%60closed_date%60%2C%0A%20%20%60agency%60%2C%0A%20%20%60agency_name%60%2C%0A%20%20%60complaint_type%60%2C%0A%20%20%60descriptor%60%2C%0A%20%20%60location_type%60%2C%0A%20%20%60incident_zip%60%2C%0A%20%20%60incident_address%60%2C%0A%20%20%60street_name%60%2C%0A%20%20%60cross_street_1%60%2C%0A%20%20%60cross_street_2%60%2C%0A%20%20%60intersection_street_1%60%2C%0A%20%20%60intersection_street_2%60%2C%0A%20%20%60address_type%60%2C%0A%20%20%60city%60%2C%0A%20%20%60landmark%60%2C%0A%20%20%60facility_type%60%2C%0A%20%20%60status%60%2C%0A%20%20%60due_date%60%2C%0A%20%20%60resolution_description%60%2C%0A%20%20%60resolution_action_updated_date%60%2C%0A%20%20%60community_board%60%2C%0A%20%20%60bbl%60%2C%0A%20%20%60borough%60%2C%0A%20%20%60x_coordinate_state_plane%60%2C%0A%20%20%60y_coordinate_state_plane%60%2C%0A%20%20%60open_data_channel_type%60%2C%0A%20%20%60park_borough%60%2C%0A%20%20%60latitude%60%2C%0A%20%20%60longitude%60%2C%0A%20%20%60location%60%0AWHERE%0A%20%20%60created_date%60%0A%20%20%20%20BETWEEN%20%222024-01-01T16%3A23%3A16%22%20%3A%3A%20floating_timestamp%0A%20%20%20%20AND%20%222025-12-31T16%3A23%3A16%22%20%3A%3A%20floating_timestamp%0A%20%20AND%20caseless_ne%28%60agency%60%2C%20%22HPD%22%29%0AORDER%20BY%20%60created_date%60%20DESC%20NULL%20FIRST/page/filter
#
#
# #### The downloaded data contains only 911 complaints for 2024 and 2025. File excludes HPD (New York City Department of Housing Preservation and Development) because it is usually concerned only with building conditions and is not relevant to our project conceptually.
#
#
# **Data also does not include those columns:**
#     "vehicle_type",
#     "taxi_company_borough",
#     "taxi_pick_up_location",
#     "bridge_highway_name",
#     "bridge_highway_direction",
#     "road_ramp",
#     "bridge_highway_segment",
#     "due_date",
#     "resolution_description",
#     "resolution_action_updated_date",
#     "landmark",
#     "facility_type"

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Unique Key  Created Date  Closed Date Agency  \
# 0    67351762           NaN          NaN   NYPD
# 1    67344624           NaN          NaN   NYPD
# 2    67346873           NaN          NaN   NYPD
# 3    67353004           NaN          NaN   NYPD
# 4    67349434           NaN          NaN   NYPD
#
#                        Agency Name            Complaint  Complaint Detail  \
# 0  New York City Police Department  Noise - Residential  Loud Music/Party
# 1  New York City Police Department  Noise - Residential  Loud Music/Party
# 2  New York City Police Department     Blocked Driveway    Partial Access
# 3  New York City Police Department  Noise - Residential  Loud Music/Party
# 4  New York City Police Department  Noise - Residential  Loud Music/Party
#
#    Incident Zip  Status Community Board    Borough   Latitude  Longitude  \
# 0         10029  Closed    11 MANHATTAN  MANHATTAN  40.792141 -73.950097
# 1         10031  Closed    09 MANHATTAN  MANHATTAN  40.825137 -73.949447
# 2         11234  Closed     18 BROOKLYN   BROOKLYN  40.619995 -73.921167
# 3         11235  Closed     15 BROOKLYN   BROOKLYN  40.591542 -73.955979
# 4         11234  Closed     18 BROOKLYN   BROOKLYN  40.629373 -73.928005
#
#    Complaint Year  Complaint Month  Month Name Main Complaint Category  \
# 0             NaN              NaN         NaN                   Noise
# 1             NaN              NaN         NaN                   Noise
# 2             NaN              NaN         NaN       Parking & Traffic
# 3             NaN              NaN         NaN                   Noise
# 4             NaN              NaN         NaN                   Noise
#
#                                      Neighborhood
# 0                             East Harlem (South)
# 1                     Hamilton Heights-Sugar Hill
# 2                                       Flatlands
# 3  Sheepshead Bay-Manhattan Beach-Gerritsen Beach
# 4                                       Flatlands

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint', 'Complaint Detail', 'Incident Zip', 'Status',
#        'Community Board', 'Borough', 'Latitude', 'Longitude', 'Complaint Year',
#        'Complaint Month', 'Month Name', 'Main Complaint Category',
#        'Neighborhood'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unique Key               660 non-null    int64
#  1   Created Date             0 non-null      float64
#  2   Closed Date              0 non-null      float64
#  3   Agency                   660 non-null    object
#  4   Agency Name              660 non-null    object
#  5   Complaint                660 non-null    object
#  6   Complaint Detail         660 non-null    object
#  7   Incident Zip             660 non-null    int64
#  8   Status                   660 non-null    object
#  9   Community Board          660 non-null    object
#  10  Borough                  660 non-null    object
#  11  Latitude                 660 non-null    float64
#  12  Longitude                660 non-null    float64
#  13  Complaint Year           0 non-null      float64
#  14  Complaint Month          0 non-null      float64
#  15  Month Name               0 non-null      float64
#  16  Main Complaint Category  660 non-null    object
#  17  Neighborhood             660 non-null    object
# dtypes: float64(7), int64(2), object(9)
# memory usage: 92.9+ KB

# %% [markdown]
# #### This part is added after Kenneth modifications 3.28.2026
#
# ### Since the data is now being pulled directly from the website, the column names differ from those used in the CSV extract. I will rename them here for consistency:

# %%
# original column names
cols_old = ['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
            'complaint_type', 'descriptor', 'location_type', 'incident_zip',
            'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
            'intersection_street_1', 'intersection_street_2', 'address_type',
            'city', 'landmark', 'facility_type', 'status', 'due_date',
            'resolution_description', 'resolution_action_updated_date',
            'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
            'y_coordinate_state_plane', 'open_data_channel_type', 'park_borough',
            'latitude', 'longitude', 'location']

# target column names
cols_new = ['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
            'Problem (formerly Complaint Type)',
            'Problem Detail (formerly Descriptor)', 'Location Type', 'Incident Zip',
            'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
            'Intersection Street 1', 'Intersection Street 2', 'Address Type',
            'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
            'Resolution Description', 'Resolution Action Updated Date',
            'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
            'Y Coordinate (State Plane)', 'Open Data Channel Type', 'Park Borough',
            'Latitude', 'Longitude', 'Location']

# build mapping
rename_dict = dict(zip(cols_old, cols_new))

# apply rename
df = df.rename(columns=rename_dict)

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint', 'Complaint Detail', 'Incident Zip', 'Status',
#        'Community Board', 'Borough', 'Latitude', 'Longitude', 'Complaint Year',
#        'Complaint Month', 'Month Name', 'Main Complaint Category',
#        'Neighborhood'],
#       dtype='object')

# %%
df["Created Date"] = pd.to_datetime(
    df["Created Date"],
    format="%m/%d/%Y %I:%M:%S %p",
    errors="coerce"
)

df["Closed Date"] = pd.to_datetime(
    df["Created Date"],
    format="%m/%d/%Y %I:%M:%S %p",
    errors="coerce"
)

# %%
df["Complaint Year"] = df["Created Date"].dt.year

# %%
df["Complaint Month"] = df["Created Date"].dt.month

# %%
print(df["Complaint Year"].unique())
df["Complaint Month"].unique()
# Out:
# [nan]
# array([nan])

# %%
df["Month Name"] = pd.to_datetime(df["Complaint Month"], format="%m").dt.month_name()

# %%
df["Month Name"].unique()
# Out:
# array([nan], dtype=object)

# %%
df["Agency"].unique()
# Out:
# array(['NYPD'], dtype=object)

# %%
#df = df[df["agency"] != "HPD"]
#df["agency"].unique()

# %%
#df["Problem (formerly Complaint Type)"].unique()

# %%
#for the ease of use - we will rename the columns
df = df.rename(columns={
    "Problem (formerly Complaint Type)": "Complaint",
    "Problem Detail (formerly Descriptor)": "Complaint Detail"
})

# %%
df = df.rename(columns={
    'X Coordinate (State Plane)': "X Coordinate",
    'Y Coordinate (State Plane)': "Y Coordinate"
})

# %%
grouping_complaints = (
    df.groupby(["Agency", "Complaint","Complaint Detail"])
      .size()
      .reset_index(name="count")
)

# %%
grouping_complaints
# Out:
#    Agency            Complaint                Complaint Detail  count
# 0    NYPD     Blocked Driveway                       No Access     95
# 1    NYPD     Blocked Driveway                  Partial Access     21
# 2    NYPD      Illegal Parking               Blocked Bike Lane      3
# 3    NYPD      Illegal Parking               Blocked Crosswalk     11
# 4    NYPD      Illegal Parking                 Blocked Hydrant    106
# 5    NYPD      Illegal Parking                Blocked Sidewalk     20
# 6    NYPD      Illegal Parking    Commercial Overnight Parking     49
# 7    NYPD      Illegal Parking  Double Parked Blocking Traffic     11
# 8    NYPD      Illegal Parking  Double Parked Blocking Vehicle     10
# 9    NYPD      Illegal Parking          License Plate Obscured      2
# 10   NYPD      Illegal Parking    Overnight Commercial Storage      3
# 11   NYPD      Illegal Parking     Parking Permit Improper Use      7
# 12   NYPD      Illegal Parking   Posted Parking Sign Violation     35
# 13   NYPD      Illegal Parking        Unauthorized Bus Layover      2
# 14   NYPD  Noise - Residential                Banging/Pounding     67
# 15   NYPD  Noise - Residential                Loud Music/Party    205
# 16   NYPD  Noise - Residential                    Loud Talking     11
# 17   NYPD  Noise - Residential                 Loud Television      2

# %%
#if you want your own table :
# grouping_complaints.to_excel("complaints_by_agency_problem.xlsx", index=False)

# %%
df.isnull().sum()
# Out:
# Unique Key                   0
# Created Date               660
# Closed Date                660
# Agency                       0
# Agency Name                  0
# Complaint                    0
# Complaint Detail             0
# Incident Zip                 0
# Status                       0
# Community Board              0
# Borough                      0
# Latitude                     0
# Longitude                    0
# Complaint Year             660
# Complaint Month            660
# Month Name                 660
# Main Complaint Category      0
# Neighborhood                 0
# dtype: int64

# %% [markdown]
# We have 5,597,360 rows and for:
# - 102,672 we do not have Location
# - 102,639 we do not have X Coordinate
# - 102,458 we do not have Y Coordinate

# %%
df[(df["Location"].notna()) & (df["X Coordinate"].isna())]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df[(df["Location"].notna()) & (df["X Coordinate"].isna())]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Location'

# %%
rows_with_location_missing_x = df[
    df["Location"].notna() & df["X Coordinate"].isna()
]

print("Number of rows:", len(rows_with_location_missing_x))  # should print 33
rows_with_location_missing_x.head()

# %%
df[(df["Location"].notna()) & (df["Y Coordinate"].isna())]

# %%
df[["Location","X Coordinate"]].isna().value_counts()
# Out:
# Location  X Coordinate
# False     False           985
# True      True             15
# Name: count, dtype: int64

# %% [markdown]
# 5,494,689 rows → both Location and X Coordinate (State Plane) exist ✅
#
# 102,639 rows → Location is missing, X Coordinate is missing ❌
#
# 33 rows → X Coordinate exists but Location is missing ⚠

# %%
rows_with_location_missing_x = df[
    df["X Coordinate"].notna() & df["Location"].isna()
]

len(rows_with_location_missing_x)  # should print 33
rows_with_location_missing_x
# Out:
# Empty DataFrame
# Columns: [Unique Key, Created Date, Closed Date, Agency, Agency Name, Complaint, Complaint Detail, Location Type, Incident Zip, Incident Address, Street Name, Cross Street 1, Cross Street 2, Intersection Street 1, Intersection Street 2, Address Type, City, Landmark, Facility Type, Status, Due Date, Resolution Description, Resolution Action Updated Date, Community Board, BBL, Borough, X Coordinate, Y Coordinate, Open Data Channel Type, Park Borough, Latitude, Longitude, Location, Complaint Year, Complaint Month, Month Name]
# Index: []

# %% [markdown]
# We are removing all 33 where we do not have location and both Y and X coordinates

# %%
# Keep only rows where Location is not null
df = df[df["Location"].notna()]

# Quick check
df["Location"].isna().sum()  # should be 0
# Out:
# np.int64(0)

# %% [markdown]
# ## We have some missing Compaint Detail, maybe we can replace the name of the Detaio wiht the compaint name

# %%
# Filter rows where Complaint Detail is null
missing_detail_rows = df[df["Complaint Detail"].isna()]

# Get unique Complaint values that have missing details
missing_complaints = missing_detail_rows["Complaint"].unique()

# Display them
missing_complaints
# Out:
# array(['Illegal Fireworks', 'Panhandling', 'Encampment'], dtype=object)

# %%
for complaint in missing_complaints:
    rows_with_details = df[(df["Complaint"] == complaint) & (df["Complaint Detail"].notna())]
    print(f"Complaint: {complaint}, Rows with details: {len(rows_with_details)}")
    display(rows_with_details.head())
# Out:
# Complaint: Illegal Fireworks, Rows with details: 0
# Empty DataFrame
# Columns: [Unique Key, Created Date, Closed Date, Agency, Agency Name, Complaint, Complaint Detail, Location Type, Incident Zip, Incident Address, Street Name, Cross Street 1, Cross Street 2, Intersection Street 1, Intersection Street 2, Address Type, City, Landmark, Facility Type, Status, Due Date, Resolution Description, Resolution Action Updated Date, Community Board, BBL, Borough, X Coordinate, Y Coordinate, Open Data Channel Type, Park Borough, Latitude, Longitude, Location, Complaint Year, Complaint Month, Month Name]
# Index: []
# Complaint: Panhandling, Rows with details: 0
# Empty DataFrame
# Columns: [Unique Key, Created Date, Closed Date, Agency, Agency Name, Complaint, Complaint Detail, Location Type, Incident Zip, Incident Address, Street Name, Cross Street 1, Cross Street 2, Intersection Street 1, Intersection Street 2, Address Type, City, Landmark, Facility Type, Status, Due Date, Resolution Description, Resolution Action Updated Date, Community Board, BBL, Borough, X Coordinate, Y Coordinate, Open Data Channel Type, Park Borough, Latitude, Longitude, Location, Complaint Year, Complaint Month, Month Name]
# Index: []
# Complaint: Encampment, Rows with details: 0
# Empty DataFrame
# Columns: [Unique Key, Created Date, Closed Date, Agency, Agency Name, Complaint, Complaint Detail, Location Type, Incident Zip, Incident Address, Street Name, Cross Street 1, Cross Street 2, Intersection Street 1, Intersection Street 2, Address Type, City, Landmark, Facility Type, Status, Due Date, Resolution Description, Resolution Action Updated Date, Community Board, BBL, Borough, X Coordinate, Y Coordinate, Open Data Channel Type, Park Borough, Latitude, Longitude, Location, Complaint Year, Complaint Month, Month Name]
# Index: []

# %% [markdown]
# so it is almmost always miising detail fot those in a missing_complaints list, except for Asbestos, Illegal Fireworks, and Homeless Person Assistance

# %%
df[df["Complaint Detail"]=='Loud Music/Party']
# Out:
#      Unique Key Created Date Closed Date Agency  \
# 0      67351762          NaT         NaT   NYPD
# 1      67344624          NaT         NaT   NYPD
# 3      67353004          NaT         NaT   NYPD
# 4      67350526          NaT         NaT   NYPD
# 5      67349434          NaT         NaT   NYPD
# ..          ...          ...         ...    ...
# 947    67351841          NaT         NaT   NYPD
# 956    67349424          NaT         NaT   NYPD
# 967    67345744          NaT         NaT   NYPD
# 989    67353603          NaT         NaT   NYPD
# 994    67352980          NaT         NaT   NYPD
#
#                          Agency Name                Complaint  \
# 0    New York City Police Department      Noise - Residential
# 1    New York City Police Department      Noise - Residential
# 3    New York City Police Department      Noise - Residential
# 4    New York City Police Department       Noise - Commercial
# 5    New York City Police Department      Noise - Residential
# ..                               ...                      ...
# 947  New York City Police Department  Noise - Street/Sidewalk
# 956  New York City Police Department      Noise - Residential
# 967  New York City Police Department       Noise - Commercial
# 989  New York City Police Department  Noise - Street/Sidewalk
# 994  New York City Police Department      Noise - Residential
#
#      Complaint Detail               Location Type  Incident Zip  \
# 0    Loud Music/Party  Residential Building/House       10029.0
# 1    Loud Music/Party  Residential Building/House       10031.0
# 3    Loud Music/Party  Residential Building/House       11235.0
# 4    Loud Music/Party            Store/Commercial       10031.0
# 5    Loud Music/Party  Residential Building/House       11234.0
# ..                ...                         ...           ...
# 947  Loud Music/Party             Street/Sidewalk       11417.0
# 956  Loud Music/Party  Residential Building/House       10306.0
# 967  Loud Music/Party            Store/Commercial       11249.0
# 989  Loud Music/Party             Street/Sidewalk       11433.0
# 994  Loud Music/Party  Residential Building/House       10031.0
#
#                Incident Address          Street Name     Cross Street 1  \
# 0           50 EAST  104 STREET     EAST  104 STREET     MADISON AVENUE
# 1          549 WEST  144 STREET     WEST  144 STREET   AMSTERDAM AVENUE
# 3         2416 EAST   14 STREET     EAST   14 STREET           AVENUE X
# 4         1635 AMSTERDAM AVENUE     AMSTERDAM AVENUE   WEST  140 STREET
# 5             1760 UTICA AVENUE         UTICA AVENUE           AVENUE I
# ..                          ...                  ...                ...
# 947  137-20 CROSS BAY BOULEVARD  CROSS BAY BOULEVARD   VAN WICKLEN ROAD
# 956             655 TYSENS LANE          TYSENS LANE      FALCON AVENUE
# 967             97 WYTHE AVENUE         WYTHE AVENUE  NORTH   10 STREET
# 989           108-12 157 STREET           157 STREET         108 AVENUE
# 994        620 WEST  141 STREET     WEST  141 STREET           BROADWAY
#
#         Cross Street 2 Intersection Street 1 Intersection Street 2  \
# 0          PARK AVENUE        MADISON AVENUE           PARK AVENUE
# 1             BROADWAY      AMSTERDAM AVENUE              BROADWAY
# 3             AVENUE Y              AVENUE X              AVENUE Y
# 4     WEST  141 STREET      WEST  140 STREET      WEST  141 STREET
# 5             AVENUE J              AVENUE I              AVENUE J
# ..                 ...                   ...                   ...
# 947         149 AVENUE      VAN WICKLEN ROAD            149 AVENUE
# 956          MILL ROAD         FALCON AVENUE             MILL ROAD
# 967  NORTH    9 STREET     NORTH   10 STREET     NORTH    9 STREET
# 989         109 AVENUE            108 AVENUE            109 AVENUE
# 994    RIVERSIDE DRIVE              BROADWAY       RIVERSIDE DRIVE
#
#     Address Type           City             Landmark Facility Type  Status  \
# 0        ADDRESS       NEW YORK     EAST  104 STREET           NaN  Closed
# 1        ADDRESS       NEW YORK     WEST  144 STREET           NaN  Closed
# 3        ADDRESS       BROOKLYN     EAST   14 STREET           NaN  Closed
# 4        ADDRESS       NEW YORK     AMSTERDAM AVENUE           NaN  Closed
# 5        ADDRESS       BROOKLYN         UTICA AVENUE           NaN  Closed
# ..           ...            ...                  ...           ...     ...
# 947      ADDRESS     OZONE PARK  CROSS BAY BOULEVARD           NaN  Closed
# 956      ADDRESS  STATEN ISLAND          TYSENS LANE           NaN  Closed
# 967      ADDRESS       BROOKLYN         WYTHE AVENUE           NaN  Closed
# 989      ADDRESS        JAMAICA           157 STREET           NaN  Closed
# 994      ADDRESS       NEW YORK     WEST  141 STREET           NaN  Closed
#
#     Due Date                             Resolution Description  \
# 0        NaN  The New York City Police Department responded ...
# 1        NaN  The New York City Police Department responded ...
# 3        NaN  The New York City Police Department responded ...
# 4        NaN  The Police Department reviewed your complaint ...
# 5        NaN  The New York City Police Department responded ...
# ..       ...                                                ...
# 947      NaN  The New York City Police Department responded ...
# 956      NaN  The New York City Police Department responded ...
# 967      NaN  The New York City Police Department responded ...
# 989      NaN  The New York City Police Department responded ...
# 994      NaN  The New York City Police Department responded ...
#
#     Resolution Action Updated Date   Community Board           BBL  \
# 0          2026-01-01T00:40:35.000      11 MANHATTAN  1.016080e+09
# 1          2026-01-01T01:03:44.000      09 MANHATTAN  1.020760e+09
# 3          2026-01-01T00:57:34.000       15 BROOKLYN  3.074150e+09
# 4          2026-01-01T00:41:20.000      09 MANHATTAN  1.020570e+09
# 5          2026-01-01T00:44:28.000       18 BROOKLYN  3.077750e+09
# ..                             ...               ...           ...
# 947        2025-12-31T21:54:23.000         10 QUEENS  4.114090e+09
# 956        2025-12-31T21:42:30.000  03 STATEN ISLAND  5.039830e+09
# 967        2025-12-31T21:37:54.000       01 BROOKLYN  3.023030e+09
# 989        2026-01-01T05:35:47.000         12 QUEENS           NaN
# 994        2025-12-31T21:26:16.000      09 MANHATTAN  1.020880e+09
#
#            Borough  X Coordinate  Y Coordinate Open Data Channel Type  \
# 0        MANHATTAN      998068.0      227879.0                 MOBILE
# 1        MANHATTAN      998241.0      239901.0                 ONLINE
# 3         BROOKLYN      996476.0      154794.0                 ONLINE
# 4        MANHATTAN      998220.0      238974.0                 MOBILE
# 5         BROOKLYN     1004234.0      168582.0                 ONLINE
# ..             ...           ...           ...                    ...
# 947         QUEENS     1027800.0      183913.0                 ONLINE
# 956  STATEN ISLAND      952579.0      144231.0                 ONLINE
# 967       BROOKLYN      995673.0      201973.0                 MOBILE
# 989         QUEENS     1041031.0      192326.0                 ONLINE
# 994      MANHATTAN      997264.0      239545.0                 MOBILE
#
#       Park Borough   Latitude  Longitude  \
# 0        MANHATTAN  40.792141 -73.950097
# 1        MANHATTAN  40.825137 -73.949447
# 3         BROOKLYN  40.591542 -73.955979
# 4        MANHATTAN  40.822593 -73.949525
# 5         BROOKLYN  40.629373 -73.928005
# ..             ...        ...        ...
# 947         QUEENS  40.671368 -73.843006
# 956  STATEN ISLAND  40.562500 -74.113985
# 967       BROOKLYN  40.721039 -73.958790
# 989         QUEENS  40.694385 -73.795239
# 994      MANHATTAN  40.824162 -73.952978
#
#                                      Location  Complaint Year  \
# 0    POINT (-73.950097072847 40.792140506424)             NaN
# 1     POINT (-73.949447237231 40.82513729001)             NaN
# 3    POINT (-73.955979130812 40.591541524842)             NaN
# 4    POINT (-73.949525045155 40.822592971648)             NaN
# 5    POINT (-73.928004925688 40.629372641946)             NaN
# ..                                        ...             ...
# 947  POINT (-73.843006354489 40.671368329875)             NaN
# 956  POINT (-74.113984885689 40.562500040828)             NaN
# 967   POINT (-73.958790492502 40.72103857354)             NaN
# 989   POINT (-73.79523910737 40.694385062079)             NaN
# 994  POINT (-73.952978057044 40.824161664793)             NaN
#
#      Complaint Month Month Name
# 0                NaN        NaN
# 1                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN
# 5                NaN        NaN
# ..               ...        ...
# 947              NaN        NaN
# 956              NaN        NaN
# 967              NaN        NaN
# 989              NaN        NaN
# 994              NaN        NaN
#
# [325 rows x 36 columns]

# %%
df[df["Complaint Detail"].str.contains("Fireworks", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [Unique Key, Created Date, Closed Date, Agency, Agency Name, Complaint, Complaint Detail, Location Type, Incident Zip, Incident Address, Street Name, Cross Street 1, Cross Street 2, Intersection Street 1, Intersection Street 2, Address Type, City, Landmark, Facility Type, Status, Due Date, Resolution Description, Resolution Action Updated Date, Community Board, BBL, Borough, X Coordinate, Y Coordinate, Open Data Channel Type, Park Borough, Latitude, Longitude, Location, Complaint Year, Complaint Month, Month Name]
# Index: []

# %% [markdown]
# Some complaints don’t have a Complaint Detail because the complaint itself fully describes the issue. I will replace missing Complaint Detail values with the Complaint value.

# %%
df.loc[df["Complaint Detail"].isna(), "Complaint Detail"] = df["Complaint"]

# %%
df[df["Complaint Detail"].isna()]
# Out:
# Empty DataFrame
# Columns: [Unique Key, Created Date, Closed Date, Agency, Agency Name, Complaint, Complaint Detail, Location Type, Incident Zip, Incident Address, Street Name, Cross Street 1, Cross Street 2, Intersection Street 1, Intersection Street 2, Address Type, City, Landmark, Facility Type, Status, Due Date, Resolution Description, Resolution Action Updated Date, Community Board, BBL, Borough, X Coordinate, Y Coordinate, Open Data Channel Type, Park Borough, Latitude, Longitude, Location, Complaint Year, Complaint Month, Month Name]
# Index: []

# %% [markdown]
# ## we also have null values in Closed Date

# %% [markdown]
# - Created Date    0
# - Closed Date  136499

# %%
missing_closed_rows = df[df["Closed Date"].isna()]

# Get unique Complaint values for those rows
missing_closed_complaints = missing_closed_rows["Complaint"].unique()

# Display them
missing_closed_complaints
# Out:
# array(['Noise - Residential', 'Blocked Driveway', 'Noise - Commercial',
#        'Illegal Parking', 'Illegal Fireworks', 'Noise - Street/Sidewalk',
#        'Lost Property', 'Boilers', 'Street Light Condition',
#        'Illegal Dumping', 'Elevator', 'Traffic Signal Condition',
#        'Consumer Complaint', 'Noise - Vehicle', 'Water System',
#        'Dead Animal', 'Panhandling', 'Animal-Abuse', 'Damaged Tree',
#        'Encampment', 'General Construction/Plumbing',
#        'For Hire Vehicle Complaint', 'Traffic', 'Street Condition',
#        'Maintenance or Facility', 'Taxi Complaint', 'Noise',
#        'Snow or Ice', 'Noise - Helicopter', 'Building/Use', 'Drinking',
#        'Food Establishment', 'Indoor Sewage', 'Noise - House of Worship',
#        'Dirty Condition', 'Smoking or Vaping', 'Sidewalk Condition',
#        'Sewer', 'Indoor Air Quality', 'Abandoned Vehicle',
#        'Non-Emergency Police Matter', 'Derelict Vehicles', 'Rodent',
#        'Illegal Posting', 'Lead', 'Emergency Response Team (ERT)',
#        'Residential Disposal Complaint', 'Mobile Food Vendor',
#        'Drug Activity', 'Asbestos', 'Obstruction', 'Cannabis Retailer',
#        'Air Quality', 'Graffiti', 'Water Quality',
#        'Real Time Enforcement', 'Litter Basket Request',
#        'Non-Residential Heat'], dtype=object)

# %% [markdown]
# I do not think it is relevan to our analysis so I will leave this as is

# %% [markdown]
# ## Remove agencies that are not neighborhood-quality related

# %%
remove_agencies = [
    'TLC',     # taxi / ride complaints
    'DCWP',    # consumer complaints
    'OTI',     # LinkNYC / payphones
]

df = df[~df['Agency'].isin(remove_agencies)]

# %% [markdown]
# ###  Remove complaint types that are not useful

# %%
remove_complaints = [
    'Lost Property',
    'Found Property',
    'Taxi Compliment',
    'Taxi Report',
    'For Hire Vehicle Report',
    'For Hire Vehicle Complaint',
    'Green Taxi Complaint',
    'Green Taxi Report',
    'Dispatched Taxi Complaint',
    'Taxi Licensee Complaint',
    'Public Payphone Complaint',
    'LinkNYC',
    'Consumer Complaint'
]

df = df[~df['Complaint'].isin(remove_complaints)]

# %% [markdown]
# ### Remove vague / useless rows

# %%
df = df[~df['Complaint'].isin(['Unspecified'])]

# %% [markdown]
# ### Remove information requests (not complaints)

# %%
remove_complaint_detail = [
    'Lead Kit Request (Residential) (L10)',
    'New Basket',
    'Replacement Basket',
    'New Bus Stop Shelter Placement'
]

df = df[~df['Complaint Detail'].isin(remove_complaint_detail)]

# %% [markdown]
# ### Optional: Remove very rare complaint types ????

# %%
counts = df['Complaint'].value_counts()

df = df[df['Complaint'].isin(counts[counts > 100].index)]

# %%
df['Complaint'].value_counts().head(20)
# Out:
# Complaint
# Noise - Residential    285
# Illegal Parking        259
# Blocked Driveway       116
# Name: count, dtype: int64

# %%
df['Agency'].value_counts()
# Out:
# Agency
# NYPD    660
# Name: count, dtype: int64

# %% [markdown]
# the one left for a 311 is noise complaint - so we can leave it

# %% [markdown]
# ### Create the mapping dictionary

# %%
category_map = {

# --------------------
# NOISE
# --------------------
"Noise - Residential": "Noise",
"Noise - Street/Sidewalk": "Noise",
"Noise - Commercial": "Noise",
"Noise - Vehicle": "Noise",
"Noise - Park": "Noise",
"Noise - Helicopter": "Noise",
"Noise": "Noise",

# --------------------
# PARKING & TRAFFIC
# --------------------
"Illegal Parking": "Parking & Traffic",
"Blocked Driveway": "Parking & Traffic",
"Traffic": "Parking & Traffic",

# --------------------
# SANITATION
# --------------------
"Dirty Condition": "Sanitation & Trash",
"Missed Collection": "Sanitation & Trash",
"Illegal Dumping": "Sanitation & Trash",
"Litter Basket Complaint": "Sanitation & Trash",
"Litter Basket Request": "Sanitation & Trash",
"Residential Disposal Complaint": "Sanitation & Trash",
"Commercial Disposal Complaint": "Sanitation & Trash",
"Dumpster Complaint": "Sanitation & Trash",
"Street Sweeping Complaint": "Sanitation & Trash",
"Obstruction": "Sanitation & Trash",
"Dead Animal": "Sanitation & Trash",

# --------------------
# RODENTS
# --------------------
"Rodent": "Rodents & Pests",

# --------------------
# STREET / INFRASTRUCTURE
# --------------------
"Street Condition": "Street & Infrastructure",
"Street Light Condition": "Street & Infrastructure",
"Sidewalk Condition": "Street & Infrastructure",
"Curb Condition": "Street & Infrastructure",
"Traffic Signal Condition": "Street & Infrastructure",
"Broken Parking Meter": "Street & Infrastructure",
"Street Sign - Damaged": "Street & Infrastructure",
"Street Sign - Missing": "Street & Infrastructure",
"Street Sign - Dangling": "Street & Infrastructure",
"Highway Condition": "Street & Infrastructure",
"Bridge Condition": "Street & Infrastructure",

# --------------------
# WATER / SEWER
# --------------------
"Water System": "Water & Sewer",
"Sewer": "Water & Sewer",
"Water Quality": "Water & Sewer",
"Water Conservation": "Water & Sewer",

# --------------------
# BUILDINGS
# --------------------
"Building/Use": "Buildings & Construction",
"General Construction/Plumbing": "Buildings & Construction",
"Construction Safety Enforcement": "Buildings & Construction",
"Elevator": "Buildings & Construction",
"Boilers": "Buildings & Construction",
"Electrical": "Buildings & Construction",
"Plumbing": "Buildings & Construction",
"Facade Insp Safety Pgm": "Buildings & Construction",

# --------------------
# PARKS / TREES
# --------------------
"Damaged Tree": "Parks & Trees",
"Dead/Dying Tree": "Parks & Trees",
"Overgrown Tree/Branches": "Parks & Trees",
"Illegal Tree Damage": "Parks & Trees",
"New Tree Request": "Parks & Trees",
"Root/Sewer/Sidewalk Condition": "Parks & Trees",
"Maintenance or Facility": "Parks & Trees",
"Violation of Park Rules": "Parks & Trees",
"Animal in a Park": "Parks & Trees",

# --------------------
# PUBLIC SAFETY
# --------------------
"Drug Activity": "Public Safety",
"Drinking": "Public Safety",
"Disorderly Youth": "Public Safety",
"Non-Emergency Police Matter": "Public Safety",
"Animal-Abuse": "Public Safety",

# --------------------
# ENVIRONMENT
# --------------------
"Air Quality": "Environment & Air Quality",
"Hazardous Materials": "Environment & Air Quality",
"Asbestos": "Environment & Air Quality"
}

# %%
#Apply the mapping
df["Main Complaint Category"] = df["Complaint"].map(category_map)

# %%
#Remove rows that did not map
df = df[df["Main Complaint Category"].notna()]

# %%
df["Main Complaint Category"].value_counts()
# Out:
# Main Complaint Category
# Parking & Traffic    375
# Noise                285
# Name: count, dtype: int64

# %%
#sorted(df["Complaint"].unique())

# %% [markdown]
# ## Remove additional columns to
# - groupby operations faster
# - visualizations easier
# - code cleaner

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint', 'Complaint Detail', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate', 'Y Coordinate',
#        'Open Data Channel Type', 'Park Borough', 'Latitude', 'Longitude',
#        'Location', 'Complaint Year', 'Complaint Month', 'Month Name',
#        'Main Complaint Category'],
#       dtype='object')

# %% [markdown]
# **we do not need those:**
# BBL
# X Coordinate
# Y Coordinate
# Location Type
#
# Incident Address
# Street Name
# Cross Street 1
# Cross Street 2
# Intersection Street 1
# Intersection Street 2
# Address Type
# Landmark
# Location
#
# **These describe how agencies processed the complaint: - remove as well**
# Due Date
# Resolution Description
# Resolution Action Updated Date
# Facility Type
# Open Data Channel Type
# Park Borough

# %% [markdown]
# for mapping we can keep:
#     'Latitude', 'Longitude', 'Borough', 'Community Board'

# %%
drop_cols = [
'Incident Address','Street Name','Cross Street 1','Cross Street 2',
'Intersection Street 1','Intersection Street 2','Address Type',
'Landmark','Location',
'Due Date','Resolution Description','Resolution Action Updated Date',
'Facility Type','Open Data Channel Type','Park Borough',
'BBL','X Coordinate','Y Coordinate','Location Type','City'
]

df = df.drop(columns=drop_cols)

# %%
df.head()
# Out:
#    Unique Key Created Date Closed Date Agency  \
# 0    67351762          NaT         NaT   NYPD
# 1    67344624          NaT         NaT   NYPD
# 2    67346873          NaT         NaT   NYPD
# 3    67353004          NaT         NaT   NYPD
# 5    67349434          NaT         NaT   NYPD
#
#                        Agency Name            Complaint  Complaint Detail  \
# 0  New York City Police Department  Noise - Residential  Loud Music/Party
# 1  New York City Police Department  Noise - Residential  Loud Music/Party
# 2  New York City Police Department     Blocked Driveway    Partial Access
# 3  New York City Police Department  Noise - Residential  Loud Music/Party
# 5  New York City Police Department  Noise - Residential  Loud Music/Party
#
#    Incident Zip  Status Community Board    Borough   Latitude  Longitude  \
# 0       10029.0  Closed    11 MANHATTAN  MANHATTAN  40.792141 -73.950097
# 1       10031.0  Closed    09 MANHATTAN  MANHATTAN  40.825137 -73.949447
# 2       11234.0  Closed     18 BROOKLYN   BROOKLYN  40.619995 -73.921167
# 3       11235.0  Closed     15 BROOKLYN   BROOKLYN  40.591542 -73.955979
# 5       11234.0  Closed     18 BROOKLYN   BROOKLYN  40.629373 -73.928005
#
#    Complaint Year  Complaint Month Month Name Main Complaint Category
# 0             NaN              NaN        NaN                   Noise
# 1             NaN              NaN        NaN                   Noise
# 2             NaN              NaN        NaN       Parking & Traffic
# 3             NaN              NaN        NaN                   Noise
# 5             NaN              NaN        NaN                   Noise

# %% [markdown]
# ## need to fix zipcode - make it str

# %%
# Make sure Incident Zip is numeric (drop decimals) and then convert to string
df['Incident Zip'] = df['Incident Zip'].fillna(0).astype(int).astype(str)

# Optional: pad with leading zeros if needed (NYC zips are 5 digits)
df['Incident Zip'] = df['Incident Zip'].str.zfill(5)

# %% [markdown]
# ## Lets see what we missing now

# %%
df.isnull().sum()
# Out:
# Unique Key                   0
# Created Date               660
# Closed Date                660
# Agency                       0
# Agency Name                  0
# Complaint                    0
# Complaint Detail             0
# Incident Zip                 0
# Status                       0
# Community Board              0
# Borough                      0
# Latitude                     0
# Longitude                    0
# Complaint Year             660
# Complaint Month            660
# Month Name                 660
# Main Complaint Category      0
# dtype: int64

# %% [markdown]
# #### we just converted all zipcodes to str and missing one to 0 so need to chcek how many is still missing

# %%
missing_after = (df['Incident Zip'] == '00000').sum()
print("Missing/invalid ZIP codes after cleaning:", missing_after)
# Out:
# Missing/invalid ZIP codes after cleaning: 0

# %% [markdown]
# ## save your cleaned dataset so we don’t have to repeat all the preprocessing

# %%
# Save your cleaned DataFrame to a CSV
df.to_csv("311_cleaned.csv", index=False)

# Optionally, save as a pickle for faster reloading with all dtypes preserved
df.to_pickle("311_cleaned.pkl")

# %% [markdown]
# ## We have missing zipcodes

# %% [markdown]
# - Incident Zip   524 missing zipcodes

# %% [markdown]
# ## --- KENNETH'S CHECKPOINT: PRODUCTION EXPORT ---
# ### Maryla's analysis above highlights the scale of the 5.6M row dataset.
# ### To ensure the Neighborhood Mapping and Dashboard run at peak performance,
# ### I am now exporting a cleaned version of the data.

# %%
# Columns Maryla identified for removal + rows without coordinates
drop_cols = [
    'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
    'Intersection Street 1', 'Intersection Street 2', 'Address Type',
    'Landmark', 'Location', 'Due Date', 'Resolution Description', 
    'Resolution Action Updated Date', 'Facility Type', 'Open Data Channel Type', 
    'Park Borough', 'BBL', 'X Coordinate (State Plane)', 'Y Coordinate (State Plane)', 
    'Location Type', 'City'
]

# Renamng the columns to the final project standard
df = df.rename(columns={
    "Problem (formerly Complaint Type)": "Complaint",
    "Problem Detail (formerly Descriptor)": "Complaint Detail"
})

# Creating the optimized dataframe
# Dropping the junk columns and remove rows with missing Lat/Long
df_final = df.drop(columns=drop_cols, errors='ignore').dropna(subset=['Latitude', 'Longitude'])

# Patching the missing Complaint Details with the main Category
df_final.loc[df_final["Complaint Detail"].isna(), "Complaint Detail"] = df_final["Complaint"]

# Making a shortcut to save memory
# Exporting this so we don't have to run the heavy loading/date conversion cells again
df_final.to_csv("311_Service_Requests_CLEANED.csv", index=False)

print(f"--- Production File Created ---")
print(f"Old Dataset Size: {len(df):,} rows")
print(f"New Optimized Size: {len(df_final):,} rows")

# Re-assigning df to the clean version so the Neighborhood Mapping below is lightning fast
df = df_final
del df_final # Freeing up RAM immediately so my computer runs faster
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/zy/7bttbfwn0xs410gwc5brp0c80000gn/T/ipykernel_7078/2682513862.py in ?()
#      15 })
#      16
#      17 # Creating the optimized dataframe
#      18 # Dropping the junk columns and remove rows with missing Lat/Long
# ---> 19 df_final = df.drop(columns=drop_cols, errors='ignore').dropna(subset=['Latitude', 'Longitude'])
#      20
#      21 # Patching the missing Complaint Details with the main Category
#      22 df_final.loc[df_final["Complaint Detail"].isna(), "Complaint Detail"] = df_final["Complaint"]
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['Latitude', 'Longitude']

# %% [markdown]
# ## Mapping Neighborhoods & Fixing ZIP Codes
#
# #### We have 524 missing ZIP codes and no neighborhood labels. Using the Latitude and Longitude coordinates, we will perform a spatial join with official NYC Shapefiles to:
#
# #### Assign a Neighborhood (NTA) to every row so the HTML dashboard dropdown works.
#
# #### Backfill missing ZIP codes where the data currently shows '00000'.

# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /opt/anaconda3/lib/python3.13/site-packages (1.1.2)
# Requirement already satisfied: numpy>=1.24 in /opt/anaconda3/lib/python3.13/site-packages (from geopandas) (2.1.3)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: shapely>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

# Loading the GeoJSON boundaries from the local files
nta_path = "2020_Neighborhood_Tabulation_Areas_(NTAs)_20260318.geojson"
zip_path = "Modified_Zip_Code_Tabulation_Areas_(MODZCTA)_20260318.geojson"

print("Loading local NYC Shapefiles...")
nta_gdf = gpd.read_file(nta_path)
zips_gdf = gpd.read_file(zip_path)

# Safety check for column names
if 'ntaname' in nta_gdf.columns:
    nta_gdf = nta_gdf.rename(columns={'ntaname': 'NTAName'})
if 'modzcta' in zips_gdf.columns:
    zips_gdf = zips_gdf.rename(columns={'modzcta': 'MODZCTA'})

# Preparing the 311 Data for Spatial Analysis
gdf_311 = gpd.GeoDataFrame(
    df, 
    geometry=gpd.points_from_xy(df.Longitude, df.Latitude),
    crs="EPSG:4326"
)

# Mapping to the Neighborhoods
print("Mapping coordinates to Neighborhood names...")
gdf_311 = gpd.sjoin(gdf_311, nta_gdf[['NTAName', 'geometry']], how="left", predicate="within")
gdf_311 = gdf_311.rename(columns={'NTAName': 'Neighborhood'})

# Dropping 'index_right' so the next join doesn't crash
if 'index_right' in gdf_311.columns:
    gdf_311 = gdf_311.drop(columns=['index_right'])

# Backfilling Missing ZIP Codes
missing_zip_mask = gdf_311['Incident Zip'].isin(['00000', '0', None, '', 'Unspecified'])
print(f"Backfilling {missing_zip_mask.sum()} missing ZIP codes using spatial join...")

# Only running the second join if there are actually missing ZIPs to find
if missing_zip_mask.any():
    zips_joined = gpd.sjoin(gdf_311[missing_zip_mask], zips_gdf[['MODZCTA', 'geometry']], how="left", predicate="within")
    
    # Updating the main 'Incident Zip' column
    gdf_311.loc[zips_joined.index, 'Incident Zip'] = zips_joined['MODZCTA']
    
    # Clean up index_right again after the second join
    if 'index_right' in gdf_311.columns:
        gdf_311 = gdf_311.drop(columns=['index_right'])

# Final Cleanup stuff
df = pd.DataFrame(gdf_311.drop(columns='geometry'))

print("\n--- Processing Complete ---")
print(f"Total Neighborhoods mapped: {df['Neighborhood'].notnull().sum()}")
print(f"Remaining '00000' ZIP codes: {(df['Incident Zip'] == '00000').sum()}")

# Saving the absolute final version
df.to_csv("NYC_311_Master_2024_2025.csv", index=False)
print("Master file saved! Ready for visualization.")
# Out:
# Loading local NYC Shapefiles...
# Mapping coordinates to Neighborhood names...
# Backfilling 0 missing ZIP codes using spatial join...
#
# --- Processing Complete ---
# Total Neighborhoods mapped: 660
# Remaining '00000' ZIP codes: 0
# Master file saved! Ready for visualization.

# %%
# A quick look at the top 10 neighborhoods
top_neighborhoods = df['Neighborhood'].value_counts().head(10)
print("--- TOP 10 NEIGHBORHOODS BY COMPLAINT VOLUME ---")
print(top_neighborhoods)

# Checking a few random rows to see the new Neighborhood column in action
df[['Complaint', 'Neighborhood', 'Incident Zip']].sample(5)
# Out:
# --- TOP 10 NEIGHBORHOODS BY COMPLAINT VOLUME ---
# Neighborhood
# Maspeth                     22
# Jackson Heights             20
# Crown Heights (South)       13
# Woodhaven                   12
# North Corona                10
# East Village                10
# Ocean Hill                  10
# Williamsbridge-Olinville    10
# Gravesend (West)            10
# Glendale                     9
# Name: count, dtype: int64
#                Complaint               Neighborhood Incident Zip
# 574     Blocked Driveway               North Corona        11368
# 168     Blocked Driveway     Flushing-Willets Point        11355
# 707  Noise - Residential               East Village        10009
# 484      Illegal Parking         Ozone Park (North)        11416
# 601  Noise - Residential  Bedford-Stuyvesant (West)        11216

# %%
# Creating a 'Summary' file that is tiny but has all the chart data
df_summary = df.groupby(['Neighborhood', 'Complaint', 'Borough']).size().reset_index(name='Count')
df_summary.to_csv("NYC_311_Summary_Counts.csv", index=False)

# %%
import pandas as pd
import time
import os

# Instructions for the Team:
# 1. Ensure all CSV and GeoJSON files are in the same folder as this notebook.
# 2. Use 'df_summary' for 90% of our charts/visuals (it is fast).
# 3. Use 'df' ONLY for deep analysis requiring raw coordinates or timestamps.

# These are the relative paths. As long as these files are in your project folder, this code will work on any computer.
SUMMARY_FILE = "NYC_311_Summary_Counts.csv"
MASTER_FILE = "NYC_311_Master_2024_2025.csv"

print("Files Loaded:")
print("-" * 40)

# Loading the summary data
# Use df_summary for 90% of the charts, maps, and basic analysis.
if os.path.exists(SUMMARY_FILE):
    df_summary = pd.read_csv(SUMMARY_FILE)
    print(f"SUMMARY LOADED: Use 'df_summary' for quick charts and dashboarding.")
else:
    print(f"MISSING: {SUMMARY_FILE} not found. Run the cleaning cells above.")

# Loading the Master Data
# Use this df only if you need raw coordinates or specific timestamp details.
if os.path.exists(MASTER_FILE):
    print(f"LOADING MASTER FILE: This is ~1.1GB...")
    start_time = time.time()
    
    # Loading the file
    df = pd.read_csv(MASTER_FILE, low_memory=False)
    
    elapsed = round(time.time() - start_time, 2)
    print(f"MASTER LOADED: Use 'df' for deep analysis. (Load time: {elapsed}s)")
else:
    print(f"MISSING: {MASTER_FILE} not found.")

print("-" * 40)
print("The files are ready.")
# Out:
# Files Loaded:
# ----------------------------------------
# SUMMARY LOADED: Use 'df_summary' for quick charts and dashboarding.
# LOADING MASTER FILE: This is ~1.1GB...
# MASTER LOADED: Use 'df' for deep analysis. (Load time: 0.01s)
# ----------------------------------------
# The files are ready.

# %%
file_path = "NYC_311_Master_2024_2025.csv"

if os.path.exists(file_path):
    # 1. Check the actual file size on your hard drive
    file_size_gb = os.path.getsize(file_path) / (1024**3)
    print(f"File Size on Disk: {file_size_gb:.4f} GB")

    # 2. Fast Row Count (Standard for Mac/Linux/Jupyter)
    # This avoids loading the file into Pandas
    print("Counting rows...")
    count = sum(1 for line in open(file_path, 'r', encoding='utf-8', errors='ignore'))
    print(f"Actual Row Count: {count:,}")

    # 3. Check the first 5 rows to see if columns are correct
    print("\nFirst 5 Rows Peek:")
    display(pd.read_csv(file_path, nrows=5))
else:
    print("File not found! Check your folder.")
# Out:
# File Size on Disk: 0.0001 GB
# Counting rows...
# Actual Row Count: 661
#
# First 5 Rows Peek:
#    Unique Key  Created Date  Closed Date Agency  \
# 0    67351762           NaN          NaN   NYPD
# 1    67344624           NaN          NaN   NYPD
# 2    67346873           NaN          NaN   NYPD
# 3    67353004           NaN          NaN   NYPD
# 4    67349434           NaN          NaN   NYPD
#
#                        Agency Name            Complaint  Complaint Detail  \
# 0  New York City Police Department  Noise - Residential  Loud Music/Party
# 1  New York City Police Department  Noise - Residential  Loud Music/Party
# 2  New York City Police Department     Blocked Driveway    Partial Access
# 3  New York City Police Department  Noise - Residential  Loud Music/Party
# 4  New York City Police Department  Noise - Residential  Loud Music/Party
#
#    Incident Zip  Status Community Board    Borough   Latitude  Longitude  \
# 0         10029  Closed    11 MANHATTAN  MANHATTAN  40.792141 -73.950097
# 1         10031  Closed    09 MANHATTAN  MANHATTAN  40.825137 -73.949447
# 2         11234  Closed     18 BROOKLYN   BROOKLYN  40.619995 -73.921167
# 3         11235  Closed     15 BROOKLYN   BROOKLYN  40.591542 -73.955979
# 4         11234  Closed     18 BROOKLYN   BROOKLYN  40.629373 -73.928005
#
#    Complaint Year  Complaint Month  Month Name Main Complaint Category  \
# 0             NaN              NaN         NaN                   Noise
# 1             NaN              NaN         NaN                   Noise
# 2             NaN              NaN         NaN       Parking & Traffic
# 3             NaN              NaN         NaN                   Noise
# 4             NaN              NaN         NaN                   Noise
#
#                                      Neighborhood
# 0                             East Harlem (South)
# 1                     Hamilton Heights-Sugar Hill
# 2                                       Flatlands
# 3  Sheepshead Bay-Manhattan Beach-Gerritsen Beach
# 4                                       Flatlands
